# %%
import numpy as np
from sklearn.manifold import TSNE
import plotly.express as px

# %%
from genre_onehot import *
from anime_details import *

# %%
id_genre = np.array(id_genre)
print(id_genre.shape)
# Out:
# (9431, 43)

# %%
tsne = TSNE(n_components=3, random_state=1)
projections = tsne.fit_transform(id_genre)

# %%
ratings = [each['rating'] for each in anime_list_dict]

# %%
genres = [str(each['genre']) for each in anime_list_dict]

# %%
ids = [each['anime_id'] for each in anime_list_dict]

# %%
names = [each['name'] for each in anime_list_dict]

# %%
for each in anime_list_dict:
    try:
        _ = each['members']
    except KeyError:
        print(each['anime_id'])
# Out:
# 8134
# 11033
# 20843
# 2628
# 5693
# 30445
# 32503
# 12665
# 25875
# 32382
# 29323
# 30133
# 33105
# 28077
# 20725
# 22159
# 19557
# 23731
# 2135
# 3771
# 13595
# 5644
# 16187
# 4365
# 31101
# 5568

# %%
fig = px.scatter_3d(projections,
                   x=0, y=1, z=2,
                hover_name=names,
                   size = members,
                    size_max = 20
                   )
# fig.update_traces(marker_size=2)
fig.show()
# Out:
# <div>                            <div id="47232389-28ac-4b76-84fc-e390671aa30a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47232389-28ac-4b76-84fc-e390671aa30a")) {                    Plotly.newPlot(                        "47232389-28ac-4b76-84fc-e390671aa30a",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>0=%{x}<br>1=%{y}<br>2=%{z}<br>size=%{marker.size}<extra></extra>", "hovertext": ["Kimi no Na wa.", "Fullmetal Alchemist: Brotherhood", "Gintama\u00b0", "Steins;Gate", "Gintama&#039;", "Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou", "Hunter xp Hunter (2011)", "Ginga Eiyuu Densetsu", "Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare", "Gintama&#039;: Enchousen", "Clannad: After Story", "Koe no Katachi", 
# ...
